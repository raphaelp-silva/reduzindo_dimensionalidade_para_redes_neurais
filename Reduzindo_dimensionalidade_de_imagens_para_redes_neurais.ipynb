# %% [markdown]
# <a href="https://colab.research.google.com/github/raphaelp-silva/reduzindo_dimensionalidade_para_redes_neurais/blob/main/Reduzindo_dimensionalidade_de_imagens_para_redes_neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Montando o google drive
from google.colab import drive
drive.mount('/content/drive')

# Buscando a imagem a ser convertida no drive
file_path_in_drive = '/de0983f1-c1a7-42ee-9809-fb16a4d781d7.jpg'

# Verificando os arquivos carregados
import io
import cv2
import numpy as np
from PIL import Image

# Abrindo a imagem
img = Image.open(file_path_in_drive)
img.show()

# Convertendo a imagem caso seja preciso
img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
cv2.imwrite('/content/raphael.png', img_cv)  # Saving the converted image
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# True

# %%
import cv2
import matplotlib.pyplot as plt

# Carregar a imagem colorida, corrigindo o caminho do arquivo:
image = cv2.imread('/content/raphael.png')  # Alterado para 'raphael.png', que foi salvo na célula anterior.

# Verificar se a imagem foi carregada corretamente
if image is None:
    print("Erro ao carregar a imagem. Verifique o caminho do arquivo.")
else:
    # Converter para imagem em escala de cinza (0 a 255)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Converter para imagem binarizada (0 e 255)
    _, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

    # Exibir as imagens
    plt.figure(figsize=(12, 4))

    # Exibir imagem original colorida
    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Imagem Colorida')
    plt.axis('off')

    # Exibir imagem em níveis de cinza
    plt.subplot(1, 3, 2)
    plt.imshow(gray_image, cmap='gray')
    plt.title('Imagem em Níveis de Cinza')
    plt.axis('off')

    # Exibir imagem binarizada
    plt.subplot(1, 3, 3)
    plt.imshow(binary_image, cmap='gray')
    plt.title('Imagem Binarizada')
    plt.axis('off')

    plt.show()
